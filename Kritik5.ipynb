# %%
import matplotlib.pyplot as plt
import random

# TODO: Implement the Chaos Game algorithm
#1. Initialize a random seed point within the triangle
#2. Roll the die and move the point half the distance to the chosen vertex.
#3. Repeat and collect the points in a list
# Remember to start plotting points after a dozen rolls
# Initialize the vertices of the triangle and the plot
# Vertices of an equilateral triangle
vertices = [(0, 0), (1, 0), (0.5, 0.866)] #A = (0,0), B = (1,0), C = (0.5, 0.866)

# A function to check whether point (x, y)
# Lies inside the triangle formed by
# AO, 0), (1, 0) and (0.5, 0.866)

def isInside(x1, y1, ×2, y2, ×3, у3, x, у):
    def area (x1, y1, X2, y2, ×3, у3):
        return abs ((x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1- y2)) / 2.0)
    A = area(x1, y1, ×2, y2, x3, y3)
    A1 = area(х, у, Х2, у2, х3, у3)
    A2 = area(x1, у1, х, у, х3, у3)
    A3 = area(x1, y1, ×2, у2, x, у)

    return A == A1 + A2 + A3 #Check if the sum of the areas matches the total area

# Prompting the user for a seed point
while True:
    try:
    seed_x = float (input ("Enter the x-coordinate of the seed point: "))
    seed_y = float (input ("Enter the y-coordinate of the seed point: "))
    if isInside(O, 0, 1, 0, 0.5, 0.866, seed _x, seed _y) :
        print ("Valid seed point entered.")
        break
    else:
        print ("The point is not inside the triangle. Please try again.")
except ValueError:
    print("Invalid input. Please enter numerical values.")

#This is your starting point 
seed=(seed_x, seed_y)

#Initialize a list where you will store your points (x_t,y_t),
# starting with your seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
      num_steps = int(input ("Enter the number of steps: "))
    if num_steps › 0:
        print(f"Number of steps set to {num_steps}.")
        break
    else:
        print("Please enter a positive integer.")
except ValueError:
    print("Invalid input. Please enter a positive integer.")

for i in range (num_steps) :
    #choose a random vertex to move toward from the list 'vertices'
    #you can use the python code random. randint (0, 2) to choose a random integer between 0 and 2. Then you can use that random integer as the index for a vertex.
    next_vertex_index = random.rindint(0,2)
    #your code should look like "next _vertex = vertex a random choice of index]"
    next_vertex=vertices[next_vertex_index]

    last_point = points[-1] #retrieve the last point in the list

    #create the next point by moving from the last point, i.e. pointsI-11, to 
    #the midpoint of the line formed by that point and the random vertex 
    #you just chose.
        
    #you may have to look up the formula for the midpoint of a line in the plane.

    next_point = ((last_point[0] + next_vertex[0])/2, (last_point[-1] + next_vertex[1])/2)

    #add the new point to your list of points points append (...)

    points.append(next_point)

#Function to plot the solution set
def plot_solution (points) :
    plt.scatter([p[0] for p in points], [pli] for p in points], s=0.1)
    plt.show

#plot your points 
plot_solution (points)

#Despite randomness, the method of moving halfway to the chosen vertex ensures that points always converge to the Sierpinski triangle. This is because the fractal structure is an attractor for the system. It's surprising how randomness combined with a geometric rule can create a structured and predictable pattern. Ultimately, this demonstrates the deterministric rule and how the randomness of the die roll only affects the sequence of moves, but the geoemetry characterized by a discrete time dynamical system ensures that all points lie within the fractal. All in all, the Chaos Game demostrates highlights how deterministic chaos can arise from simple systems with an element of randomness.
