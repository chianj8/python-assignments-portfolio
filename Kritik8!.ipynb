# %%
#4a

def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f, a function that returns a tuple (grad_x, grad_y)
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0  # Initialize x and y with the initial point
    
    for i in range(num_iterations):
        # Obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x, y)
        
        # Update x and y by taking a step in the opposite direction of the gradient
        x = x - alpha * grad_x
        y = y - alpha * grad_y
    
    return x, y

# %%
#4b

# Function f1(x, y) = x^2 + y^2
def fun_1(x, y):
    return x**2 + y**2

# Gradient of f1(x, y): grad_f_1(x, y)
def grad_f_1(x, y):
    grad_x = 2 * x  # Partial derivative with respect to x
    grad_y = 2 * y  # Partial derivative with respect to y
    return grad_x, grad_y

def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f, a function that returns a tuple (grad_x, grad_y)
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0  # Initialize x and y with the initial point
    
    for i in range(num_iterations):
        # Obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x, y)
        
        # Update x and y by taking a step in the opposite direction of the gradient
        x = x - alpha * grad_x
        y = y - alpha * grad_y
    
    return x, y

# Test case 1: (x0, y0) = (0.1, 0.1), α = 0.1, max iterations = 10
x0_1, y0_1 = 0.1, 0.1
alpha_1 = 0.1
iterations_1 = 10
result_1 = gradient_descent(x0_1, y0_1, fun_1, grad_f_1, alpha_1, iterations_1)
print(f"Test case 1 result: {result_1}")

# Test case 2: (x0, y0) = (-1, 1), α = 0.01, max iterations = 100
x0_2, y0_2 = -1, 1
alpha_2 = 0.01
iterations_2 = 100
result_2 = gradient_descent(x0_2, y0_2, fun_1, grad_f_1, alpha_2, iterations_2)
print(f"Test case 2 result: {result_2}")
# Out:
# Test case 1 result: (0.010737418240000003, 0.010737418240000003)
# Test case 2 result: (-0.13261955589475316, 0.13261955589475316)

# %%
#4c

import numpy as np

# Function f2(x, y) = 1 - exp(-x^2 - (y - 2)^2) - 2 * exp(-x^2 - (y + 2)^2)
def fun_2(x, y):
    return 1 - np.exp(-x**2 - (y - 2)**2) - 2 * np.exp(-x**2 - (y + 2)**2)

# Gradient of f2(x, y)
def grad_f_2(x, y):
    # Partial derivative with respect to x
    grad_x = 2 * x * np.exp(-x**2 - (y - 2)**2) + 4 * x * np.exp(-x**2 - (y + 2)**2)
    
    # Partial derivative with respect to y
    grad_y = 2 * (y - 2) * np.exp(-x**2 - (y - 2)**2) - 4 * (y + 2) * np.exp(-x**2 - (y + 2)**2)
    
    return grad_x, grad_y


def gradient_descent(x0, y0, f, grad_f, alpha, num_iterations):
    """
    Parameters:
    x0, y0: Initial point for the descent.
    f: a function of two variables
    grad_f: the gradient of f, a function that returns a tuple (grad_x, grad_y)
    alpha: Learning rate.
    num_iterations: Number of iterations to perform.
    
    Returns:
    (x, y): The coordinates of the final point after gradient descent.
    """
    x, y = x0, y0  # Initialize x and y with the initial point
    
    for i in range(num_iterations):
        # Obtain the gradient of f at (x, y)
        grad_x, grad_y = grad_f(x, y)
        
        # Update x and y by taking a step in the opposite direction of the gradient
        x = x - alpha * grad_x
        y = y - alpha * grad_y
    
    return x, y

# Test case 1: (x0, y0) = (0, 1), α = 0.01, max iterations = 10000
x0_1, y0_1 = 0, 1
alpha_1 = 0.01
iterations_1 = 10000
result_1 = gradient_descent(x0_1, y0_1, fun_2, grad_f_2, alpha_1, iterations_1)
print(f"Test case 1 result: {result_1}")

# Test case 2: (x0, y0) = (0, -1), α = 0.01, max iterations = 10000
x0_2, y0_2 = 0, -1
alpha_2 = 0.01
iterations_2 = 10000
result_2 = gradient_descent(x0_2, y0_2, fun_2, grad_f_2, alpha_2, iterations_2)
print(f"Test case 2 result: {result_2}")

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# Define the function
def fun_2(x, y):
    return 1 - np.exp(-x**2 - (y - 2)**2) - 2 * np.exp(-x**2 - (y + 2)**2)

# Generate data points for the plot
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_2(x, y)  # Apply the function to get the z values

# Create the plot
fig = plt.figure()
ax = plt.axes(projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')

# Set labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(x, y)')

# Show the plot
plt.show()
# Out:
# Test case 1 result: (0.0, 2.0000009002751056)
# Test case 2 result: (0.0, 2.0000009002751056)
